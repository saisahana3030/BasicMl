# %% [markdown]
# <a href="https://colab.research.google.com/github/gunupudilakshmipujitha/BasicMl/blob/APPL_EDA/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTANT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READ THE DATASET('TITANIC')

# %%
log=pd.read_csv('titanic_train.csv')
log.head(8)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
#
# [8 rows x 12 columns]

# %% [markdown]
# # TO KNOW THE VALUES ARE NULL OR NOT

# %%
log.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %% [markdown]
# # To Know What Datatype It Is

# %%
log.Name.dtype
# Out:
# dtype('O')

# %%
log.Sex.dtype
# Out:
# dtype('O')

# %% [markdown]
# # LINE PLOT

# %%
sns.lineplot(data=log,x="Age",y="Sex")
plt.show()

# %% [markdown]
# # COUNT PLOT

# %%
sns.set_style('darkgrid')
sns.countplot(x='Survived',hue='Sex',data=log,palette='BuGn')

# %%
sns.set_style('darkgrid')
sns.countplot(x='Survived',hue='Pclass',data=log,palette='cubehelix')

# %%
sns.countplot(x='SibSp',data=log,palette='Blues_r')

# %% [markdown]
# # BAR PLOT

# %%
sns.barplot(data=log,x='Pclass',y="Survived")

# %% [markdown]
# # DISTPLOT

# %%
sns.distplot(log['Age'].dropna(),color='green',bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # BOX-PLOT

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='Pclass',y='Age',data=log,palette='Dark2_r')

# %% [markdown]
# # SCATTER PLOT

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='Pclass',y='Age',data=log,palette='Dark2_r')

# %%
sns.pairplot(log)

# %% [markdown]
# # HEAT-MAP-(NULL VALUES)

# %%
sns.heatmap(log.isnull())

# %% [markdown]
# # CLEANING DATASET

# %%
log.drop('Cabin',axis=1,inplace=True)

# %%
log.head(88)
# Out:
#     PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0             1         0       3  ...         A/5 21171   7.2500         S
# 1             2         1       1  ...          PC 17599  71.2833         C
# 2             3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3             4         1       1  ...            113803  53.1000         S
# 4             5         0       3  ...            373450   8.0500         S
# ..          ...       ...     ...  ...               ...      ...       ...
# 83           84         0       1  ...            113059  47.1000         S
# 84           85         1       2  ...        SO/C 14885  10.5000         S
# 85           86         1       3  ...           3101278  15.8500         S
# 86           87         0       3  ...        W./C. 6608  34.3750         S
# 87           88         0       3  ...   SOTON/OQ 392086   8.0500         S
#
# [88 rows x 11 columns]
